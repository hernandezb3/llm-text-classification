# %% [markdown]
# add information about the train, validation, and testing datasets
# how the data have been wrangled
# - how'd we get the data from .txt to .csv
# - how'd we redact
# - how'd we determine the ideal sample size
# - how'd we split
